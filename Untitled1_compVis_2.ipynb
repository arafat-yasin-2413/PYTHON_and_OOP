# %% [markdown]
# <a href="https://colab.research.google.com/github/arafat-yasin-2413/PYTHON_and_OOP/blob/main/Untitled1_compVis_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2
from google.colab.patches import cv2_imshow

# %%
mina_img = cv2.imread("/content/Better Future.jpg")

# %%
# cv2_imshow(mina_img)
cv2_imshow(mina_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1440x960>

# %%
# mina_img[0][0]
mina_img[0][0]
# Out:
# array([219, 204,  88], dtype=uint8)

# %%
# cv2_imshow(mina_img[75][69])
cv2_imshow(mina_img[23][54])
# Out:
# <PIL.Image.Image image mode=L size=1x3>

# %%
# len(mina_img)
len(mina_img)
# Out:
# 960

# %%
# mina_img.shape
mina_img.shape
# Out:
# (960, 1440, 3)

# %%
# mina_img[126][125]
mina_img[124][232]
# Out:
# array([232, 241, 245], dtype=uint8)
